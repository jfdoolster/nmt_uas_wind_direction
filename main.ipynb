# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from wind_calc import calculate_density, calculate_vector_winds, calculate_vector_winds_error
from wind_plotter import wind_adjustment_plotter

# %%
rawdata_path = os.path.abspath(os.path.join('.', 'data', 'level0.csv'))

level0 = pd.read_csv(rawdata_path, parse_dates=['Timestamp', 'TS'])

df_out = calculate_density(level0)
df_out = calculate_vector_winds(df_out, uav_heading=True)
df_out = calculate_vector_winds_error(df_out, uav_heading=True)

# %%
fig = wind_adjustment_plotter(df_out)

# %%
df_out[['Timestamp','Seconds','T','P','Rho','Rho_err','Sc','WD','U','U_err','V','V_err','W']]
# Out:
#                             Timestamp      Seconds      T       P       Rho  \
# 0    2023-04-19 07:10:05.669701-07:00     0.000000  16.71  887.15  1.066212
# 1    2023-04-19 07:10:05.863445-07:00     0.193744  16.75  887.17  1.066089
# 2    2023-04-19 07:10:06.062895-07:00     0.393194  16.74  887.16  1.066114
# 3    2023-04-19 07:10:06.263440-07:00     0.593739  16.67  887.18  1.066395
# 4    2023-04-19 07:10:06.463066-07:00     0.793365  16.42  887.14  1.067268
# ...                               ...          ...    ...     ...       ...
# 7298 2023-04-19 07:34:25.263631-07:00  1459.593930  17.92  887.30  1.061959
# 7299 2023-04-19 07:34:25.462950-07:00  1459.793249  17.47  887.29  1.063592
# 7300 2023-04-19 07:34:25.663665-07:00  1459.993964  17.53  887.28  1.063360
# 7301 2023-04-19 07:34:25.862912-07:00  1460.193211  17.37  887.28  1.063946
# 7302 2023-04-19 07:34:26.064072-07:00  1460.394371  17.73  887.28  1.062629
#
#        Rho_err        Sc          WD         U     U_err         V     V_err  \
# 0     0.014091  3.447984  188.673191  0.519950  0.201001  3.408555  0.279528
# 1     0.014089  3.082295  186.603394  0.354451  0.186591  3.061846  0.278214
# 2     0.014089  3.434812  179.990555 -0.000566  0.202216  3.434812  0.280979
# 3     0.014094  3.064798  204.245968  1.258574  0.175866  2.794455  0.275282
# 4     0.014109  3.050915  202.285725  1.156985  0.177037  2.823025  0.275547
# ...        ...       ...         ...       ...       ...       ...       ...
# 7298  0.014017  4.112997  174.020728 -0.428445  0.281188  4.090621  0.221314
# 7299  0.014045  4.923419  168.749966 -0.960514  0.309105  4.828817  0.226849
# 7300  0.014041  4.951929  172.987249 -0.604582  0.312487  4.914884  0.223121
# 7301  0.014051  4.852158  171.682531 -0.701903  0.308023  4.801122  0.223987
# 7302  0.014029  4.260853  180.326205  0.024258  0.287417  4.260784  0.219256
#
#              W
# 0    -0.127214
# 1    -0.417548
# 2    -0.448790
# 3    -0.308593
# 4    -0.258427
# ...        ...
# 7298  0.452054
# 7299  0.400801
# 7300  0.240085
# 7301  0.271028
# 7302  0.150118
#
# [7303 rows x 13 columns]
